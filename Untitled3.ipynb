# %% [markdown]
# <a href="https://colab.research.google.com/github/MeetRathodCoding/basic-javascript-coding/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("/content/car_sales_data.csv")

dataset.head(10)
# Out:
#          Date       Salesperson      Customer Name Car Make  Car Model  \
# 0  2022-08-01   Monica Moore MD        Mary Butler   Nissan     Altima
# 1  2023-03-15      Roberto Rose     Richard Pierce   Nissan      F-150
# 2  2023-04-29      Ashley Ramos       Sandra Moore     Ford      Civic
# 3  2022-09-04    Patrick Harris       Johnny Scott     Ford     Altima
# 4  2022-06-16        Eric Lopez      Vanessa Jones    Honda  Silverado
# 5  2022-12-18  Terry Perkins MD         John Olsen     Ford     Altima
# 6  2022-06-12      Ashley Brown       Tyler Lawson    Honda      F-150
# 7  2022-06-20     Norma Watkins       Michael Bond     Ford     Altima
# 8  2022-09-02      Scott Parker    Stephanie Smith     Ford    Corolla
# 9  2023-04-06      Andrew Smith  Ashley Moreno DDS     Ford      Civic
#
#    Car Year  Sale Price  Commission Rate  Commission Earned
# 0    2018.0     15983.0         0.070495            1126.73
# 1    2016.0     38474.0         0.134439            5172.40
# 2    2016.0     33340.0         0.114536            3818.63
# 3    2013.0     41937.0         0.092191            3866.20
# 4    2022.0     20256.0         0.113490            2298.85
# 5    2015.0     14769.0         0.077247            1140.86
# 6    2013.0     41397.0         0.142780            5910.67
# 7    2015.0     46233.0         0.071624            3311.38
# 8    2021.0     27337.0         0.099504            2720.13
# 9    2018.0     16309.0         0.149926            2445.14

# %%
dataset.tail()
# Out:
#               Date      Salesperson      Customer Name   Car Make  Car Model  \
# 582199  2023-02-16    Cole Galloway       Emily Harris      Honda  Silverado
# 582200  2023-03-25    Kevin Sanchez  Samantha Chambers     Toyota    Corolla
# 582201  2022-09-14  Brittany Castro      Shannon Sloan     Nissan    Corolla
# 582202  2023-03-11      Tony Bryant      Matthew James  Chevrolet  Silverado
# 582203  2022-10-28   William Wright    Hannah Martinez     Nissan       F-15
#
#         Car Year  Sale Price  Commission Rate  Commission Earned
# 582199    2019.0     47267.0         0.147781            6985.14
# 582200    2020.0     32702.0         0.086000            2812.37
# 582201    2014.0     40469.0         0.093290            3775.34
# 582202    2013.0     27853.0         0.070280            1957.52
# 582203       NaN         NaN              NaN                NaN

# %%
dataset.shape
# Out:
# (582204, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582204 entries, 0 to 582203
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               582204 non-null  object
#  1   Salesperson        582204 non-null  object
#  2   Customer Name      582204 non-null  object
#  3   Car Make           582204 non-null  object
#  4   Car Model          582204 non-null  object
#  5   Car Year           582203 non-null  float64
#  6   Sale Price         582203 non-null  float64
#  7   Commission Rate    582203 non-null  float64
#  8   Commission Earned  582203 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 40.0+ MB

# %%
from datetime import datetime
pd.to_datetime(dataset['Car Year'])
# Out:
# 0        1970-01-01 00:00:00.000002018
# 1        1970-01-01 00:00:00.000002016
# 2        1970-01-01 00:00:00.000002016
# 3        1970-01-01 00:00:00.000002013
# 4        1970-01-01 00:00:00.000002022
#                       ...
# 582199   1970-01-01 00:00:00.000002019
# 582200   1970-01-01 00:00:00.000002020
# 582201   1970-01-01 00:00:00.000002014
# 582202   1970-01-01 00:00:00.000002013
# 582203                             NaT
# Name: Car Year, Length: 582204, dtype: datetime64[ns]

# %%
dataset['Sale Price']=dataset['Sale Price'].astype(float)

# %%
dataset.describe()
# Out:
#             Car Year     Sale Price  Commission Rate  Commission Earned
# count  582203.000000  582203.000000    582203.000000      582203.000000
# mean     2015.993324   30010.910921         0.099978        3000.418473
# std         3.740081   11538.135697         0.028859        1480.354313
# min      2010.000000   10000.000000         0.050000         503.330000
# 25%      2013.000000   20037.000000         0.074981        1821.330000
# 50%      2016.000000   30008.000000         0.100000        2740.910000
# 75%      2019.000000   40020.000000         0.124986        3978.295000
# max      2022.000000   50000.000000         0.150000        7494.530000

# %%
dataset.nunique()
# Out:
# Date                    366
# Salesperson          243051
# Customer Name        242892
# Car Make                  5
# Car Model                 6
# Car Year                 13
# Sale Price            40001
# Commission Rate      582203
# Commission Earned    351466
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Salesperson          0
# Customer Name        0
# Car Make             0
# Car Model            0
# Car Year             1
# Sale Price           1
# Commission Rate      1
# Commission Earned    1
# dtype: int64

# %%
dataset=dataset.dropna()

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Salesperson          0
# Customer Name        0
# Car Make             0
# Car Model            0
# Car Year             0
# Sale Price           0
# Commission Rate      0
# Commission Earned    0
# dtype: int64

# %%
dataset['Car Year']=pd.DatetimeIndex(dataset['Car Year']).year

dataset['Car Year'].value_counts()
# Out:
# Car Year
# 1970    582203
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Date', 'Salesperson', 'Customer Name', 'Car Make', 'Car Model',
#        'Car Year', 'Sale Price', 'Commission Rate', 'Commission Earned'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

make_counts = dataset['Car Make'].value_counts()

plt.bar(make_counts.index, make_counts.values)
plt.xlabel('Car Make')
plt.ylabel('Count')
plt.title('Count of Car Make')
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(dataset['Commission Rate'], bins=2)
plt.xlabel('Commision Rate')
plt.ylabel('rate')
plt.title('Distribution of commision Rate')
plt.show()

# %%
carmake_counts=dataset['Car Make'].value_counts()

plt.pie(carmake_counts, labels=carmake_counts.index, autopct='%1.0f%%',startangle=90)
plt.title('Distribution of Car Make')
plt.show()

# %%
# @title Default title text
import matplotlib.pyplot as plt

model_counts = dataset['Car Model'].value_counts()

plt.scatter(model_counts.index, model_counts.values)
plt.xlabel('Model')
plt.ylabel('Count')
plt.title('Count of Items in Each Category')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
